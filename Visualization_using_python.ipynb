# %% [markdown]
# <a href="https://colab.research.google.com/github/chirudukuru/DMDW/blob/main/Visualization_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path="https://raw.githubusercontent.com/chirudukuru/DMDW/main/Toyota.csv"

# %%
import pandas as pd
data=pd.read_csv(path)

# %%
data
# Out:
#       Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0              0  13500  23.0  46986  ...         0  2000  three    1165
# 1              1  13750  23.0  72937  ...         0  2000      3    1165
# 2              2  13950  24.0  41711  ...         0  2000      3    1165
# 3              3  14950  26.0  48000  ...         0  2000      3    1165
# 4              4  13750  30.0  38500  ...         0  2000      3    1170
# ...          ...    ...   ...    ...  ...       ...   ...    ...     ...
# 1431        1431   7500   NaN  20544  ...         0  1300      3    1025
# 1432        1432  10845  72.0     ??  ...         0  1300      3    1015
# 1433        1433   8500   NaN  17016  ...         0  1300      3    1015
# 1434        1434   7250  70.0     ??  ...         0  1300      3    1015
# 1435        1435   6950  76.0      1  ...         0  1600      5    1114
#
# [1436 rows x 11 columns]

# %%
data.head()
# Out:
#    Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0           0  13500  23.0  46986  ...         0  2000  three    1165
# 1           1  13750  23.0  72937  ...         0  2000      3    1165
# 2           2  13950  24.0  41711  ...         0  2000      3    1165
# 3           3  14950  26.0  48000  ...         0  2000      3    1165
# 4           4  13750  30.0  38500  ...         0  2000      3    1170
#
# [5 rows x 11 columns]

# %%
data.tail()
# Out:
#       Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 1431        1431   7500   NaN  20544  ...         0  1300      3    1025
# 1432        1432  10845  72.0     ??  ...         0  1300      3    1015
# 1433        1433   8500   NaN  17016  ...         0  1300      3    1015
# 1434        1434   7250  70.0     ??  ...         0  1300      3    1015
# 1435        1435   6950  76.0      1  ...         0  1600      5    1114
#
# [5 rows x 11 columns]

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (1111, 11)

# %%
data.head()
# Out:
#    Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0           0  13500  23.0  46986  ...         0  2000  three    1165
# 1           1  13750  23.0  72937  ...         0  2000      3    1165
# 3           3  14950  26.0  48000  ...         0  2000      3    1165
# 4           4  13750  30.0  38500  ...         0  2000      3    1170
# 5           5  12950  32.0  61000  ...         0  2000      3    1170
#
# [5 rows x 11 columns]

# %%
plt.scatter(data['Age'],data['Price'],c='green')
plt.xlabel('Age(months)')
plt.ylabel('price')
plt.show()

# %%
plt.hist(data['KM'])
# Out:
# (array([142., 118., 111., 109., 104., 111., 111., 103., 101., 101.]),
#  array([  0.,  99., 198., 297., 396., 495., 594., 693., 792., 891., 990.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['KM'],color='green',edgecolor='white',bins=5)
plt.title("historgram of kilometer")
plt.xlabel("frequecies")
plt.ylabel("Km")
plt.show()

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid')
sns.regplot(x=data['Age'],y=data['Price'])

# %%
sns.set(style='darkgrid')
sns.regplot(x=data['Age'],y=data['Price'],marker='*',fit_reg=False)

# %%
sns.distplot(data['Age'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['Age'],kde=False) #kde=kernal density estimator
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['Age'],kde=False,bins=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x="FuelType",data=data)

# %%
sns.countplot(x="FuelType",data=data,hue='Automatic')                                                                       # hue : (optional) This parameter take column name for colour encoding.

# %%
sns.boxplot(y=data['Price'])
